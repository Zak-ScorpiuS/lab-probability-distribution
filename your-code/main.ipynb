# %% [markdown]
# # Before your start:
# - Read the README.md file.
# - Comment as much as you can and use the resources (README.md file).
# - Happy learning!

# %%
# Libraries
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions
# #### Step 1: Generate samples and test normal distribution.
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed.
#
# **Hint**: Read the documentation for `scipy.stats.norm.rvs`. The function will help you create the normal random samples.

# %%
# your code here
A = norm.rvs(50, 5, 10)
plt.hist(A)
# Out:
# (array([2., 1., 0., 1., 1., 2., 0., 1., 0., 2.]),
#  array([44.43496843, 45.65296961, 46.87097079, 48.08897196, 49.30697314,
#         50.52497432, 51.74297549, 52.96097667, 54.17897785, 55.39697902,
#         56.6149802 ]),
#  <a list of 10 Patch objects>)

# %%
B = norm.rvs(50, 5, 50)
plt.hist(B)
# Out:
# (array([ 2., 10.,  3.,  4.,  5.,  3.,  6.,  8.,  6.,  3.]),
#  array([40.5968788 , 42.43903505, 44.2811913 , 46.12334756, 47.96550381,
#         49.80766006, 51.64981631, 53.49197256, 55.33412881, 57.17628506,
#         59.01844131]),
#  <a list of 10 Patch objects>)

# %%
C = norm.rvs(50, 5, 500)
plt.hist(C)
# Out:
# (array([  5.,  10.,  36.,  71., 107., 119.,  92.,  39.,  13.,   8.]),
#  array([34.89185627, 37.90404818, 40.9162401 , 43.92843201, 46.94062392,
#         49.95281583, 52.96500775, 55.97719966, 58.98939157, 62.00158349,
#         65.0137754 ]),
#  <a list of 10 Patch objects>)

# %%
D = norm.rvs(50, 5, 5000)
plt.hist(D)
# Out:
# (array([  10.,   72.,  340.,  784., 1218., 1284.,  876.,  321.,   82.,
#           13.]),
#  array([32.58187695, 36.04202901, 39.50218106, 42.96233311, 46.42248517,
#         49.88263722, 53.34278927, 56.80294132, 60.26309338, 63.72324543,
#         67.18339748]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Step 2: Plot normal distributions.
#
# To check the shape of the samples you have just created, you can use matplotlib. For example, you can use it to plot a histogram of each sample.
#
# If you did, your outputs would be really similar to the ones below:
#
# ![normal distributions with different sample sizes](/images/ch-1.png)

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %%
"""
As the Central Limit Theorem is, the bigger the sample, the more tendency to a normal distribution we have, in our case, although the array was normally distributed, with smaller sample sizes (10 and 50), it did not look like a normal distribution curve at all, but once we increased the size to 500 and later to 5000, the curve was perfectly normally distributed.
learnings: the bigger the sample, the better to represent the population :)
"""

# %% [markdown]
# #### Bonus: Plot normal distributions.
#
# Even though you still don't know how to use matplotlib, as a bonus challenge, you can try to reproduce the plot above using the samples you have created. This plotting library will be introduced later this week, so don't worry if you don't manage to get the results you want now: you can always come back to solve this challenge later.

# %%
# your code here
mu=0
mean=50
std=5
sample_size=5000
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(17,6))
x = np.linspace(mu-3*std,mu+3*std,sample_size)
x1 = np.linspace(mu-4,mu+4,sample_size)
y = norm.pdf(x)
y1 = norm.pdf(x1)
ax1.plot(x,y)
ax2.plot(x1,y1)
plt.show()

#Octavi's way to handle the axis' and zoom the projection
#plt.sca(ax1)
#plt.axis([-3,3,0,0.42])
#plt.sca(ax2)

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# ### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# ### Challenge
#
# We assume that the probability of clicking an advertisement in a Youtube video is 0.15. We have a sample of 5 people who watched the video and we want to plot the PMF for a binomial distribution.
#
# #### Step 1: Create the binomial distribution mentioned above. Store the result in a variable called `dist`.
# **Hint**: use binom from `scipy.stats.binom`. This object takes *n* and *p* as shape parameters, where *n* is the number of independent experiments and *p* the probability of success of the experiment.

# %%
# your code here
from scipy.stats import binom
n=5
p=0.15
dist = binom(n,p)

# %% [markdown]
# #### Step 2: Plot the PMF of the distribution.
# To do it, run the code in the cell below.
#
# **Hint**: Your output should look like the one below:
#
# ![binom 10](../images/ch-2.png)

# %%
# run this code
x = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()

# %%
n=5
p=0.15
dist = binom(n,p)
x = range(n)
fig, ax = plt.subplots(1, 1)
plt.plot(x, dist.pmf(x))
#plt.vlines(x, 0, dist.pmf(x), colors='b', lw=2, alpha=0.5)
plt.show()

# %% [markdown]
# #### Step 3: Explain what you observe from the plot above.

# %%
"""
we have a probability of 0,15 to clic the ad
if  5 people watch the add, the probability of 1 people clic is 0,4x, then the probability of 2 people clic is 0,4, the probability of 3 people is 0,1, and then it goes down.
"""

# %% [markdown]
# #### Step 4: Now plot PMF with 50, 500, and 5000 visitors.
# To plot the PMF, you can copy the code given above and replace variable `dist` for the name of the variables where you have stored the new binomial objects for 50, 500 and 5000 visitors.

# %%
# your code here
n=50
p=0.15
dist = binom(n,p)
x = range(n)
fig, ax = plt.subplots(1, 1)
plt.plot(x, dist.pmf(x))
plt.show()

# %%
n=500
p=0.15
dist = binom(n,p)
x = range(n)
fig, ax = plt.subplots(1, 1)
plt.plot(x, dist.pmf(x))
plt.show()

# %%
n=5000
p=0.15
dist = binom(n,p)
x = range(n)
fig, ax = plt.subplots(1, 1)
plt.plot(x, dist.pmf(x))
plt.show()

# %% [markdown]
# #### Step 5: What did you notice from the distribution plots? Comment your findings.

# %%
"""
as the probability is low, 0.15, the center of the distribution is close to 0, and it is quite similar from a sample of 50 to a sample of 5000
"""

# %% [markdown]
# # Challenge 3
# #### Step 1: Research the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
"""
Poisson basically is the binomial distribution taken to the infinit, which means, the binomial distribution formula when n has a tendency to the infinit makes the formula become poisson distribution
"""

# %% [markdown]
# #### Step 2: A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# **Hint**: use `scipy.stats.poisson.pmf`.

# %%
from scipy.stats import poisson
#pmf(k,mu,loc=0)
avg = 300
k = 320
p = poisson.pmf(k,avg)
p
# Out:
# 0.011612348610402475

# %%
# your code here
from scipy.stats import poisson
mu = 5
mean, var, skew, kurt = poisson.stats(mu, moments='mvsk')
x = np.arange(poisson.ppf(0.00001, mu), poisson.ppf(0.9999, mu))
plt.plot(x, poisson.pmf(x, mu), 'bo', ms=8, label='poisson pmf')
plt.show()

# %% [markdown]
# #### Step 3: What is the probability of getting 60 visits?

# %%
# your code here
#poisson.pmf(k,mu,loc=0)
avg = 300
k = 60
p = poisson.pmf(k,avg)
p
# Out:
# 2.622743762294515e-64

# %% [markdown]
# #### Step 4: Create a list to store the Poisson distribution probabilities for 0 to 1000 visitors. Store your list in a variable called `arr`.

# %%
# your code here
arr=[]
for i in range(1000):
    magic_minerva = poisson.pmf(i,300)
    arr.append(magic_minerva)
arr
# Out:
# 3310100575e-13,
#  3.7284973080810205e-13,
#  5.981546483553175e-13,
#  9.545020984393356e-13,
#  1.5150826959351161e-12,
#  2.3922358356871803e-12,
#  3.757438485372861e-12,
#  5.870997633395585e-12,
#  9.125903057090625e-12,
#  1.411222122230466e-11,
#  2.1711109572780717e-11,
#  3.323129016241047e-11,
#  5.0606025628040964e-11,
#  7.667579640613254e-11,
#  1.1559165287355822e-10,
#  1.733874793103563e-10,
#  2.587872825527467e-10,
#  3.843375483456274e-10,
#  5.679865246486847e-10,
#  8.352743009539742e-10,
#  1.2223526355424312e-09,
#  1.7801251973922216e-09,
#  2.5798915904235948e-09,
#  3.7209974861881144e-09,
#  5.341144717015085e-09,
#  7.630206738592185e-09,
#  1.0848635173354153e-08,
#  1.535184222644446e-08,
#  2.1622312994995644e-08,
#  3.031165373130406e-08,
#  4.22953307878516e-08,
#  5.874351498312939e-08,
#  8.121223269557828e-08,
#  1.1175995325080651e-07,
#  1.5309582637094398e-07,
#  2.0876703596042977e-07,
#  2.8339416646209297e-07,
#  3.8296508981359804e-07,
# ...

# %% [markdown]
# #### Step 5: Plot the probabilities.
# To do it, run the code in the cell below. Your plot should look like the one below:
#
# ![poisson distribution](../images/ch-3.png)

# %%
# run this code
plt.plot(arr)
plt.show()

# %% [markdown]
# # Challenge 4 - Central Limit Theorem
#
# A delivery company needs 35 minutes to deliver a package, with a standard deviation of 8 minutes. Suppose that in one day, they deliver 200 packages.
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: What is the probability that the mean delivery time today is between 30 and 35 minutes?

# %%
# your code here
mu=35
std=8
n=200
stdnorm = std/(n**0.5)
mumin=30
mumax=35
pmumin=norm.cdf(mumin,loc=mu,scale=stdnorm)
pmumax=norm.cdf(mumax,loc=mu,scale=stdnorm)
p=pmumax-pmumin
p
# Out:
# 0.5

# %%
35 * 200 / 60
# Out:
# 116.66666666666667

# %% [markdown]
# #### Step 2: What is the probability that in total, it takes more than 115 hours to deliver all 200 packages?

# %%
# your code here
mu115=115*60
new_nu=mu115/200
print(mu115)
print(new_nu)
pmu115=norm.cdf(34.5,loc=35,scale=stdnorm)
result = 1-pmu115
result
# Out:
# 6900
# 34.5
# 0.8116204410942089

# %% [markdown]
# # Challenge 5 - Normal Variables
# The value (in thousands) of the monthly sales of a publishing company follows a normal distribution with a mean equal to 200 and a standard deviation equal to 40.
#
# <div align="center">$X → N(200,40)$</div>
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that the monthly sales are more than 300.

# %%
# your code here
mean=200
std=40
p300 = norm.cdf(300,loc=mean,scale=std)
more_than_p300 = 1-p300
more_than_p300
# Out:
# 0.006209665325776159

# %% [markdown]
# #### Step 2: Find the probability that the monthly sales fall between 160 and 240.

# %%
# your code here
m1=160
m2=240
pm1 = norm.cdf(m1,loc=mean,scale=std)
pm2 = norm.cdf(m2,loc=mean,scale=std)
prob = pm2-pm1
prob
# Out:
# 0.6826894921370859

# %% [markdown]
# #### Step 3: Find the probability that the monthly sales do not exceed 150.

# %%
# your code here
m3=150
pm3 = norm.cdf(m3,loc=mean,scale=std)
pm3
# Out:
# 0.10564977366685535

# %% [markdown]
# #### Step 4: Find the probability that the monthly sales exceed 3000.

# %%
# your code here
m4=3000
pm4 = norm.cdf(m4,loc=mean,scale=std)
result_pm4 = 1-pm4
result_pm4
# Out:
# 0.0

# %% [markdown]
# # Challenge 6 - Poisson distribution
# The mean number of violent robberies per month that are registered in a particular barrio is 4.
#
# **Hint**: `stats.poisson.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that in a particular month there is no violent robbery.

# %%
# your code here
#poisson.cdf(k,mu,loc=0)
mean=4
p1=0
poisson.cdf(p1,4)
# Out:
# 0.018315638888734182

# %% [markdown]
# #### Step 2: Find the probability that there are at least 1 robbery in a given month.

# %%
# your code here
#poisson.cdf(k,mu,loc=0)
mean=4
p1=1
octa = poisson.cdf(p1,4)
octavi=1-octa
octavi
# Out:
# 0.9084218055563291

# %% [markdown]
# #### Step 3: Find the probability that there are between 2 and 6 (inclusive) robberies in a given month.

# %%
# your code here
mean=4
p1=2
p2=6
octap1 = poisson.cdf(p1,4)
octap2 = poisson.cdf(p2,4)
octavi=octap2-octap1
octavi
# Out:
# 0.6512227160438819

# %% [markdown]
# #### Step 4: Find the probability that there are more than 2 robberies in 15 days.

# %%
# your code here
mean=2
p1=3
octap1 = poisson.cdf(3,2)
final = 1-octap1
final
# Out:
# 0.14287653950145296
